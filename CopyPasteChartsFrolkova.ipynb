# %%
import win32com.client as win32
import time
import glob
import os
#from pptx import Presentation

# %%
xlApp = win32.Dispatch('Excel.Application')
pptApp = win32.Dispatch('PowerPoint.Application')

# %%
#xlApp=win32.GetObject(Class='Excel.Application')

# %%
#продажи
try:
    sales = xlApp.Workbooks("ОттокПродажи3.xlsx")
except:
    sales = xlApp.Workbooks.Open(r"\\path\ОттокПродажи3.xlsx")
time.sleep(2)

# %%
#пп
try:
    perep=xlApp.Workbooks("ПП_разрезы2.xlsx")
except:
    perep=xlApp.Workbooks.Open(r"\\path\ПП_разрезы2.xlsx")
time.sleep(2)

# %%
ott_stat="!Обращаемость,выход в интернет + Калининград"

ott_pattern=f"{ott_stat}*"

ott_directory = '//path'

ott_file_path=glob.glob(os.path.join(ott_directory,ott_pattern))

ott_file_path[0]
# Out:
# '//avir.fortline.org/Shares/!ОБЩАЯ!/Отчетность ДКО\\!Обращаемость,выход в интернет + Калининград 24.03 .xlsx'

# %%
ott_file_name=os.path.basename(ott_file_path[0])
ott_file_name
# Out:
# '!Обращаемость,выход в интернет + Калининград 24.03 .xlsx'

# %%
#ott
try:
    ott_file=xlApp.Workbooks(ott_file_name)
except:
    ott_file=xlApp.Workbooks.Open(ott_file_path[0])
time.sleep(2)

# %%
try:
    ppt = pptApp.Presentations("ПоворотCпутникаФролкова_шаблон.pptx")
except:
    ppt = pptApp.Presentations.Open(r"\\path\ПоворотCпутникаФролкова_шаблон.pptx")
time.sleep(2)

# %%
def p_cm(points):
    result=round(points*28.5,2)
    return result

# %% [markdown]
# ## Наименования листов

# %%
sales_kln = sales.Worksheets('отток по дням +КЛН')
sales_total = sales.Worksheets('отток по дням Total')
sales_w = sales.Worksheets('Отток_понедельно')
sales_m = sales.Worksheets('Отток_помес')
sales_reg = sales.Worksheets('ОттокПоДнямРег')

# %%
    

perep_all=perep.Worksheets('графики_для_презы')

ott=ott_file.Worksheets('ИнтПогран')
ott_total=ott_file.Worksheets('Подкл_к_интернету_минус30КЛН')    
ultra=perep.Worksheets('графикиUltra')

# %% [markdown]
# ## Положения графиков

# %%
#4графика
a=p_cm(0.9)
b=p_cm(2.15)
c=p_cm(17.02)
d=p_cm(10.4)


#3+2графика
k=p_cm(0.24)
l=p_cm(2.4)
m=p_cm(17.15)
n=p_cm(7.9)
o=p_cm(10.5)
p=p_cm(13.5)


#1+1
x=p_cm(0.43)
y=p_cm(2.67)
z=p_cm(10.73)

# %%
#старые
#3+2графика
#k=p_cm(1.3)
#l=p_cm(2.4)
#m=p_cm(16.8)
#n=p_cm(7.9)
#o=p_cm(10.5)
#p=p_cm(13.5)

# %% [markdown]
# ## Ультра

# %%
# два графика
slide_index=1
sheet_name=ultra
chart_data = [
    {
        'slide_index':slide_index,
        'left':x,
        'top':y,
        'chart_index':6
    },
    {
        'slide_index':slide_index,
        'left':x,
        'top':z,
        'chart_index':7
    }
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(2)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %%
#3+2
slide_index=2
sheet_name=ultra
chart_data = [
    {
        'slide_index':slide_index,
        'left':k,
        'top':l,
        'chart_index':2
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':n,
        'chart_index':1
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':p,
        'chart_index':3
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':l,
        'chart_index':4
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':o,
        'chart_index':5
    }   
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(3)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %% [markdown]
# ## Переподключения

# %%
#пп% два графика
slide_index=8
sheet_name=perep_all
chart_data = [
    {
        'slide_index':slide_index,
        'left':x,
        'top':y,
        'chart_index':18
    },
    {
        'slide_index':slide_index,
        'left':x,
        'top':z,
        'chart_index':19
    }
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(3)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %%
#пп% пять графика
slide_index=9
sheet_name=perep_all
chart_data = [
    {
        'slide_index':slide_index,
        'left':k,
        'top':l,
        'chart_index':1
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':n,
        'chart_index':2
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':p,
        'chart_index':3
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':l,
        'chart_index':4
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':o,
        'chart_index':5
    }   
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(3)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %%
#пп штуки два графика
slide_index=10
sheet_name=perep_all
chart_data = [
    {
        'slide_index':slide_index,
        'left':x,
        'top':y,
        'chart_index':16
    },
    {
        'slide_index':slide_index,
        'left':x,
        'top':z,
        'chart_index':20
    }
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(3)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %%
#перепод штуки 5 грфиков
slide_index=11
sheet_name=perep_all
chart_data = [
    {
        'slide_index':slide_index,
        'left':k,
        'top':l,
        'chart_index':6
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':n,
        'chart_index':7
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':p,
        'chart_index':8
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':l,
        'chart_index':9
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':o,
        'chart_index':10
    }   
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(3)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %% [markdown]
# #отключ два графика
# slide_index=12
# sheet_name=perep_all
# chart_data = [
#     {
#         'slide_index':slide_index,
#         'left':x,
#         'top':y,
#         'chart_index':17
#     },
#     {
#         'slide_index':slide_index,
#         'left':x,
#         'top':z,
#         'chart_index':21
#     }
# ]
#
# for data in chart_data:
#     slide_index=data['slide_index']
#     left=data['left']
#     top=data['top']
#     chart_index=data['chart_index']
#     chart=sheet_name.ChartObjects(chart_index)
#     chart.Activate()
#     chart.Copy()
#     time.sleep(3)
#     slide = ppt.Slides(slide_index)
#     chart_paste = slide.Shapes.PasteSpecial()
#     chart_paste.Left = left
#     chart_paste.Top = top

# %%
#отключ пять графика
slide_index=13
sheet_name=perep_all
chart_data = [
    {
        'slide_index':slide_index,
        'left':k,
        'top':l,
        'chart_index':11
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':n,
        'chart_index':12
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':p,
        'chart_index':13
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':l,
        'chart_index':14
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':o,
        'chart_index':15
    }   
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(3)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %% [markdown]
# ## Продажи тотал

# %%
slide_index=3
sheet_name=sales_total
chart_data = [
    {
        'slide_index':slide_index,
        'left':a,
        'top':b,
        'chart_index':2
    },
    {
        'slide_index':slide_index,
        'left':c,
        'top':b,
        'chart_index':1
    }  
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(3)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %% [markdown]
# ## Продажи клн

# %%
slide_index=3
sheet_name=sales_kln
chart_data = [
    {
        'slide_index':slide_index,
        'left':a,
        'top':d,
        'chart_index':2
    },
    {
        'slide_index':slide_index,
        'left':c,
        'top':d,
        'chart_index':1}
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(2)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %% [markdown]
# ## Отток Регионы

# %%
#спутникик
slide_index=4
sheet_name=sales_reg
chart_data = [
    {
        'slide_index':slide_index,
        'left':a,
        'top':b,
        'chart_index':11
    },
    {
        'slide_index':slide_index,
        'left':c,
        'top':b,
        'chart_index':12
    },
    {
        'slide_index':slide_index,
        'left':a,
        'top':d,
        'chart_index':14
    },
    {
        'slide_index':slide_index,
        'left':c,
        'top':d,
        'chart_index':13
    }   
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(3)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %%
#3+2
slide_index=5
sheet_name=sales_reg
chart_data = [
    {
        'slide_index':slide_index,
        'left':k,
        'top':l,
        'chart_index':6
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':n,
        'chart_index':7
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':p,
        'chart_index':8
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':l,
        'chart_index':9
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':o,
        'chart_index':10
    }   
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(3)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %%
#3+2
slide_index=6
sheet_name=sales_reg
chart_data = [
    {
        'slide_index':slide_index,
        'left':k,
        'top':l,
        'chart_index':1
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':n,
        'chart_index':2
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':p,
        'chart_index':3
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':l,
        'chart_index':4
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':o,
        'chart_index':5
    }   
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(3)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %% [markdown]
# ## Продажи спецслайд

# %%
slide_index=16
sheet_name=sales_total
chart_data = [
    {
        'slide_index':slide_index,
        'left':a,
        'top':b,
        'chart_index':2
    },
    {
        'slide_index':slide_index,
        'left':c,
        'top':b,
        'chart_index':1
    }  
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(2)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[11], line 28
#      26 time.sleep(2)
#      27 slide = ppt.Slides(slide_index)
# ---> 28 chart_paste = slide.Shapes.PasteSpecial()
#      29 chart_paste.Left = left
#      30 chart_paste.Top = top
#
# File <COMObject <unknown>>:3, in PasteSpecial(self, DataType, DisplayAsIcon, IconFileName, IconIndex, IconLabel, Link)
#
# File C:\ProgramData\anacond\lib\site-packages\win32com\client\dynamic.py:368, in CDispatch._ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args)
#     367 def _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args):
# --> 368     result = self._oleobj_.InvokeTypes(
#     369         *(dispid, LCID, wFlags, retType, argTypes) + args
#     370     )
#     371     return self._get_good_object_(result, user, resultCLSID)
#
# ...

# %%
slide_index=16
sheet_name=sales_w
chart_data = [
    {
        'slide_index':slide_index,
        'left':a,
        'top':d,
        'chart_index':1
    },
    {
        'slide_index':slide_index,
        'left':c,
        'top':d,
        'chart_index':2
    }  
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(2)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %% [markdown]
# ## Продажи месяц

# %%
slide_index=17
sheet_name=sales_m
chart_data = [
    {
        'slide_index':slide_index,
        'left':a,
        'top':b,
        'chart_index':3
    },
    {
        'slide_index':slide_index,
        'left':c,
        'top':b,
        'chart_index':4
    },
    {
        'slide_index':slide_index,
        'left':a,
        'top':d,
        'chart_index':1
    },
    {
        'slide_index':slide_index,
        'left':c,
        'top':d,
        'chart_index':2
    }   
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(3)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %% [markdown]
# ## OTT

# %%
#2графика
try:
    slide_index=14
    sheet_name=ott_total
    chart_data = [
        {
        'slide_index':slide_index,
        'left':x,
        'top':y,
        'chart_index':1
        },
        {
        'slide_index':slide_index,
        'left':x,
        'top':z,
        'chart_index':2
        }
    ]

    for data in chart_data:
        slide_index=data['slide_index']
        left=data['left']
        top=data['top']
        chart_index=data['chart_index']    
        chart=sheet_name.ChartObjects(chart_index)
        chart.Activate()
        chart.Copy()
        time.sleep(3)
        slide = ppt.Slides(slide_index)
        chart_paste = slide.Shapes.PasteSpecial()
        chart_paste.Left = left
        chart_paste.Top = top
except:
    slide_index=14
    sheet_name=ott_total
    chart_data = [
        {
        'slide_index':slide_index,
        'left':x,
        'top':y,
        'chart_index':1
        },
        {
        'slide_index':slide_index,
        'left':x,
        'top':z,
        'chart_index':2
        }
    ]

    for data in chart_data:
        slide_index=data['slide_index']
        left=data['left']
        top=data['top']
        chart_index=data['chart_index']    
        chart=sheet_name.ChartObjects(chart_index)
        chart.Activate()
        chart.Copy()
        time.sleep(3)
        slide = ppt.Slides(slide_index)
        chart_paste = slide.Shapes.PasteSpecial()
        chart_paste.Left = left
        chart_paste.Top = top

# %%
#3+2
slide_index=15
sheet_name=ott
chart_data = [
    {
        'slide_index':slide_index,
        'left':k,
        'top':l,
        'chart_index':1
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':n,
        'chart_index':2
    },
    {
        'slide_index':slide_index,
        'left':k,
        'top':p,
        'chart_index':3
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':l,
        'chart_index':6
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':n,
        'chart_index':4
    },
    {
        'slide_index':slide_index,
        'left':m,
        'top':p,
        'chart_index':5
    }
]

for data in chart_data:
    slide_index=data['slide_index']
    left=data['left']
    top=data['top']
    chart_index=data['chart_index']    
    chart=sheet_name.ChartObjects(chart_index)
    chart.Activate()
    chart.Copy()
    time.sleep(3)
    slide = ppt.Slides(slide_index)
    chart_paste = slide.Shapes.PasteSpecial()
    chart_paste.Left = left
    chart_paste.Top = top

# %%
# %run HeatMap.ipynb

# %%
heatmap = '//path/heatmap_reg.png'

# %%
slide = ppt.Slides(7)
slide.shapes.AddPicture(heatmap,0,1,p_cm(0.1),p_cm(2.54),-1,-1)
# Out:
# <COMObject AddPicture>

# %%
ott_file.Close(False)

# %%
perep.Close(False)
